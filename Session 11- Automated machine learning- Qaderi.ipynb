# %% [markdown]
# <div style="background-color: rgba(247, 200, 115, 0.3); padding: 30px 0;">
#     <div style="max-width: 800px; margin: 0 auto; text-align: center;">
#         <h1 style="font-size: 48px; color: #cc7a00; margin-bottom: 10px;">🚀 Machine Learning 📊</h1>
#         <h3 style="font-size: 28px; color: #cc7a00; margin-bottom: 10px;">Automated Machine Learning</h3>
#         <h4 style="font-size: 18px; color: #cc7a00;"><a href="https://www.linkedin.com/in/mohammadreza-qaderi/" style="color: #1e90ff; text-decoration: none;">MohammadReza Qaderi</a></h4>
#         <h4 style="font-size: 18px; color: #cc7a00;"><a href="https://github.com/MR-Qaderi/MachineLearningCourseMaterials" style="color: #1e90ff; text-decoration: none;">GitHub Repository</a></h4>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color: #f9f9f9; border: 1px solid #ccc; padding: 15px; border-radius: 10px; font-family: Arial;">
#
# <h2 style="color: #555; text-align: center;">Automated Machine Learning with PyCaret</h2>
#
# <p>Automated Machine Learning (AutoML) is a cutting-edge approach that empowers individuals, regardless of their expertise level, to build highly performant machine learning models with minimal manual intervention. It streamlines the entire model development process, from data preprocessing to model selection and optimization.</p>
#
# <p>PyCaret, in particular, is a powerful AutoML library that stands out for its user-friendly interface and comprehensive suite of tools. It simplifies complex tasks, allowing practitioners to experiment with various algorithms, feature engineering techniques, and model configurations effortlessly.</p>
#
# <p>With the advent of AutoML and libraries like PyCaret, the field of machine learning has witnessed a paradigm shift. It democratizes machine learning by enabling a broader audience to harness its potential, accelerating the pace of innovation and problem-solving across various domains.</p>
#
# <h3 style="color: #777;">Beyond PyCaret</h3>
# <p>While PyCaret is a standout choice, it's worth noting that there are other notable AutoML libraries and platforms available. Each offers its own unique strengths and capabilities, providing users with a range of options to choose from based on their specific needs and preferences.</p>
#
# <p>Explore the world of Automated Machine Learning and discover the tools that resonate best with your workflow and objectives!</p>
#
# </div>

# %% [markdown]
# # [PyCaret Official Website](https://pycaret.org/)

# %% [markdown]
# ### Install

# %%
 # !pip install pycaret

# %% [markdown]
# ## Regression

# %%
from pycaret.regression import *
import pandas as pd

# %%
from pycaret.datasets import get_data
boston = get_data("boston")
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ### Model Setup

# %%
setup(data = boston , target = 'medv', session_id = 123)
# Out:
# <style type="text/css">
# #T_2ca8f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2ca8f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ca8f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2ca8f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ca8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ca8f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2ca8f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2ca8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ca8f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2ca8f_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_2ca8f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_069f4 th {
#   text-align: left;
# }
# ...

# %%
ada = create_model("ada")
# Out:
# <style type="text/css">
# #T_7eb51_row10_col0, #T_7eb51_row10_col1, #T_7eb51_row10_col2, #T_7eb51_row10_col3, #T_7eb51_row10_col4, #T_7eb51_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7eb51" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eb51_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7eb51_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7eb51_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7eb51_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7eb51_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7eb51_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(ada)

# %%
evaluate_model(ada)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
dt = create_model("dt")
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_5d7f5_row10_col0, #T_5d7f5_row10_col1, #T_5d7f5_row10_col2, #T_5d7f5_row10_col3, #T_5d7f5_row10_col4, #T_5d7f5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5d7f5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d7f5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5d7f5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5d7f5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5d7f5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5d7f5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5d7f5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
best = automl()

# %%
best
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='squared_error',
#                     max_depth=None, max_features=1.0, max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                     oob_score=False, random_state=123, verbose=0,
#                     warm_start=False)

# %% [markdown]
# ## Classification

# %%
import pandas as pd
from pycaret.classification import *

# %%
juice = get_data("juice")
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %% [markdown]
# Model Setup

# %%
setup(data = juice, target = "Purchase")
# Out:
# <style type="text/css">
# #T_e6847_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e6847" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6847_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e6847_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6847_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6847_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e6847_row0_col1" class="data row0 col1" >1390</td>
#     </tr>
#     <tr>
#       <th id="T_e6847_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6847_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e6847_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_e6847_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_09c42 th {
#   text-align: left;
# }
# ...

# %%
rf = create_model("rf")
# Out:
# <style type="text/css">
# #T_8f2c6_row10_col0, #T_8f2c6_row10_col1, #T_8f2c6_row10_col2, #T_8f2c6_row10_col3, #T_8f2c6_row10_col4, #T_8f2c6_row10_col5, #T_8f2c6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8f2c6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f2c6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8f2c6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8f2c6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8f2c6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8f2c6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8f2c6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8f2c6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(estimator= rf, plot = "auc")

# %%
plot_model(estimator = rf, plot = "feature")

# %% [markdown]
# ## Ensemble

# %%
knn = create_model("knn")
lr = create_model("lr")

blend = blend_models(estimator_list = [rf, knn, lr])
# Out:
# <style type="text/css">
# #T_1d243_row10_col0, #T_1d243_row10_col1, #T_1d243_row10_col2, #T_1d243_row10_col3, #T_1d243_row10_col4, #T_1d243_row10_col5, #T_1d243_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1d243" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d243_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1d243_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1d243_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1d243_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1d243_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1d243_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1d243_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(estimator= blend, plot = "auc")

# %% [markdown]
# ### Evaluation

# %%
plot_model(estimator= knn, plot = "confusion_matrix")

# %%
pred = predict_model(rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c797" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c797_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c797_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5c797_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5c797_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5c797_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5c797_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5c797_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5c797_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c797_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Clustering

# %%
jewellery = get_data("jewellery")
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
import pandas as pd
from pycaret.clustering import *

# %% [markdown]
# ### Model Setup

# %%
setup(jewellery)
# Out:
# <style type="text/css">
# #T_b1ac6_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1ac6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1ac6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b1ac6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1ac6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1ac6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b1ac6_row0_col1" class="data row0 col1" >5027</td>
#     </tr>
#     <tr>
#       <th id="T_b1ac6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1ac6_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b1ac6_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans = create_model('kmeans')
print(kmeans)
# Out:
# <style type="text/css">
# </style>
# <table id="T_37dbb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37dbb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_37dbb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_37dbb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_37dbb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_37dbb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_37dbb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37dbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37dbb_row0_col0" class="data row0 col0" >0.7207</td>
#       <td id="T_37dbb_row0_col1" class="data row0 col1" >5011.8115</td>
# ...

# %% [markdown]
# ### Plot

# %%
plot_model(kmeans, plot = 'elbow')

# %%
plot_model(kmeans, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Assign

# %%
kmeans_new = assign_model(kmeans)
kmeans_new
# Out:
#      Age  Income  SpendingScore       Savings    Cluster
# 0     58   77769       0.791329   6559.830078  Cluster 2
# 1     59   81799       0.791082   5417.661621  Cluster 2
# 2     62   74751       0.702657   9258.993164  Cluster 2
# 3     59   74373       0.765680   7346.334473  Cluster 2
# 4     87   17760       0.348778  16869.507812  Cluster 1
# ..   ...     ...            ...           ...        ...
# 500   28  101206       0.387441  14936.775391  Cluster 3
# 501   93   19934       0.203140  17969.693359  Cluster 1
# 502   90   35297       0.355149  16091.402344  Cluster 1
# 503   91   20681       0.354679  18401.087891  Cluster 1
# 504   89   30267       0.289310  14386.351562  Cluster 1
#
# [505 rows x 5 columns]
