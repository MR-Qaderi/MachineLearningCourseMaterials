# %% [markdown]
# <div style="background-color: rgba(247, 200, 115, 0.3); padding: 30px 0;">
#     <div style="max-width: 800px; margin: 0 auto; text-align: center;">
#         <h1 style="font-size: 48px; color: #cc7a00; margin-bottom: 10px;">🚀 Machine Learning 📊</h1>
#         <h3 style="font-size: 28px; color: #cc7a00; margin-bottom: 10px;">Neural Network</h3>
#         <h4 style="font-size: 18px; color: #cc7a00;"><a href="https://www.linkedin.com/in/mohammadreza-qaderi/" style="color: #1e90ff; text-decoration: none;">MohammadReza Qaderi</a></h4>
#         <h4 style="font-size: 18px; color: #cc7a00;"><a href="https://github.com/MR-Qaderi/MachineLearningCourseMaterials" style="color: #1e90ff; text-decoration: none;">GitHub Repository</a></h4>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color: #f9f9f9; border: 1px solid #ccc; padding: 15px; border-radius: 10px; font-family: Arial;">
#
# <h2 style="color: #555; text-align: center;">Introduction to Neural Networks</h2>
#
# <p>In this session, we'll delve into the fundamental concepts of neural networks, providing you with a solid foundation in this powerful area of machine learning. While we'll cover basic concepts, it's important to note that deep learning, which involves more complex neural network architectures, is a separate course altogether.</p>
#
# <h3 style="color: #777;">Key Topics Covered:</h3>
#
# <ul>
#     <li><strong>Neurons and Activation Functions:</strong> Understanding the basic building blocks of neural networks and how they process information.</li>
#     <li><strong>Layers and Architectures:</strong> Exploring how multiple layers of neurons are organized to create different types of neural networks.</li>
#     <li><strong>Training and Learning Process:</strong> Getting a grasp of how neural networks are trained to make accurate predictions on new data.</li>
#     <li><strong>Applications and Use Cases:</strong> Gaining insights into real-world applications where neural networks excel.</li>
# </ul>
#
# <p style="font-style: italic; text-align: center; color: #777;">By the end of this session, you'll have a clear understanding of the core principles behind neural networks, setting the stage for further exploration in deep learning.</p>
#
# </div>

# %% [markdown]
# ## Neural Network Overview
#
# A neural network is a powerful machine learning model inspired by the structure and functioning of the human brain. It consists of interconnected nodes, or "neurons," organized in layers.
#
# - **Input Layer**: This layer receives the initial data and passes it on to the subsequent layers.
#
# - **Hidden Layers**: These intermediate layers process the input data through a series of weighted connections and apply activation functions to produce meaningful representations.
#
# - **Output Layer**: This layer provides the final output or prediction based on the processed information from the previous layers.
#
# Neural networks are capable of learning complex relationships within data and can be applied to a wide range of tasks, including classification, regression, image recognition, and natural language processing. During training, the network adjusts the weights on the connections to minimize the difference between predicted and actual outputs, a process known as backpropagation.
#
# With deep learning, neural networks become even more powerful by incorporating many hidden layers, allowing them to learn intricate patterns in data. This makes them particularly effective for tasks with high complexity and large datasets.

# %% [markdown]
# ![1_3fA77_mLNiJTSgZFhYnU0Q.png](data:image/png;base64,...)

# %% [markdown]
# ![1_T4ARzySpEQvEnr_9pc78pg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![1_uUzr1DsZm5P6IqRXIlpfhQ.gif](data:image/gif;base64,...)

# %% [markdown]
# ![kuva_2023_04_24_225608185_c6a13c151e.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Churn.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.sample(3)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 4867          648    France  Female   34       3       0.00              1
# 146           635     Spain  Female   29       8  138296.94              2
# 3787          638   Germany    Male   27       4  135096.05              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 4867          1               0         54726.43       0
# 146           1               0        141075.51       0
# 3787          1               1        186523.72       1

# %%
Ext_NO = df[df.Exited == 0].Tenure
Ext_YES = df[df.Exited == 1].Tenure

# %%
plt.hist([Ext_NO, Ext_YES], color = ["green", "red"], label = ["Exited=NO", "Exited=YES"])

plt.xlabel("Tenure")
plt.ylabel("Count")
plt.title("Prediction")
plt.legend()

# %%
df["Gender"].replace({"Female":0, "Male":1}, inplace = True)

# %%
df.sample(2)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 7558          622     Spain       0   36       0  108960.00              2
# 2138          718     Spain       1   45       3  105266.32              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 7558          1               0        111180.30       1
# 2138          1               1        193724.51       0

# %%
df = pd.get_dummies(df,columns=['Geography'],drop_first=True)

# %%
x = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7       0.00              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
# ...

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
y_train.shape
# Out:
# (8000,)

# %%
x_test.shape
# Out:
# (2000, 11)

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# <div style="background-color: #f9f9f9; border: 1px solid #ccc; padding: 15px; border-radius: 10px; font-family: Arial;">
#
# <h2 style="color: #555; text-align: center;">Activation Functions in Neural Networks</h2>
#
# <p>Activation functions are crucial components of neural networks. They introduce non-linearity to the model, enabling it to learn complex relationships in data. Here are some commonly used activation functions:</p>
#
# <h3 style="color: #777;">1. <strong>Sigmoid Function</strong></h3>
# <p>The sigmoid function squashes the input values between 0 and 1, making it suitable for binary classification tasks. However, it can suffer from the vanishing gradient problem.</p>
#
# <h3 style="color: #777;">2. <strong>ReLU (Rectified Linear Unit)</strong></h3>
# <p>ReLU sets all negative values to zero, allowing the network to learn faster and reducing the likelihood of the vanishing gradient problem. It's widely used in deep learning models.</p>
#
# <h3 style="color: #777;">3. <strong>Tanh (Hyperbolic Tangent)</strong></h3>
# <p>Tanh function squashes the input values between -1 and 1, which can be useful in certain scenarios. It addresses the vanishing gradient problem better than the sigmoid function.</p>
#
# <h3 style="color: #777;">4. <strong>Softmax Function</strong></h3>
# <p>Softmax is often used in the output layer for multi-class classification problems. It converts the raw output scores into probabilities, ensuring they sum up to 1.</p>
#
# <h3 style="color: #777;">5. <strong>Leaky ReLU</strong></h3>
# <p>Leaky ReLU allows a small, non-zero gradient for negative input values, addressing the 'dying ReLU' problem that can occur with standard ReLU.</p>
#
# <h3 style="color: #777;">6. <strong>Swish Function</strong></h3>
# <p>Swish is a recently proposed activation function that tends to perform well in deep neural networks, often outperforming ReLU.</p>
#
# <p style="font-style: italic; text-align: center; color: #777;">Choosing the right activation function is a critical decision in designing neural networks, and it can significantly impact the model's performance.</p>
#
# </div>

# %% [markdown]
# ![activation-functions3.jpg](data:image/jpeg;base64,...)

# %%
model = keras.Sequential([
        keras.layers.Dense(30, activation = "relu"),
        keras.layers.Dense(15, activation = "relu"),
        keras.layers.Dense(1, activation = "sigmoid")
])

# %% [markdown]
# <div style="background-color: #f9f9f9; border: 1px solid #ccc; padding: 15px; border-radius: 10px; font-family: Arial;">
#
# <h2 style="color: #555; text-align: center;">Loss Functions in Neural Networks</h2>
#
# <p>Loss functions are crucial components in training neural networks. They quantify the error between predicted and actual values, guiding the model towards better performance. Here are some commonly used loss functions:</p>
#
# <h3 style="color: #777;">1. <strong>Mean Squared Error (MSE)</strong></h3>
# <p>MSE measures the average squared difference between predicted and actual values. It's widely used in regression tasks.</p>
#
# <h3 style="color: #777;">2. <strong>Binary Cross Entropy</strong></h3>
# <p>Binary Cross Entropy is used in binary classification tasks. It quantifies the difference between predicted probabilities and actual binary labels.</p>
#
# <h3 style="color: #777;">3. <strong>Categorical Cross Entropy</strong></h3>
# <p>Categorical Cross Entropy is suitable for multi-class classification problems. It quantifies the difference between predicted class probabilities and actual one-hot encoded labels.</p>
#
# <h3 style="color: #777;">4. <strong>Mean Absolute Error (MAE)</strong></h3>
# <p>MAE measures the average absolute difference between predicted and actual values. It's another commonly used loss function in regression.</p>
#
# <h3 style="color: #777;">5. <strong>Huber Loss</strong></h3>
# <p>Huber loss combines the characteristics of MSE and MAE, providing a balance between robustness to outliers and convergence speed.</p>
#
# <p style="font-style: italic; text-align: center; color: #777;">Selecting the appropriate loss function depends on the nature of the problem and the type of output the neural network is expected to produce.</p>
#
# </div>

# %% [markdown]
# ![loss-function.png](data:image/png;base64,...)

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])
model.fit(x_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 2s 2ms/step - loss: 574.3416 - accuracy: 0.6891
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 62.2423 - accuracy: 0.6802
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: 50.4805 - accuracy: 0.6842
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 47.0817 - accuracy: 0.6936
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 53.9517 - accuracy: 0.6852
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 41.5546 - accuracy: 0.6859
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 44.4905 - accuracy: 0.6925
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 42.3768 - accuracy: 0.6836
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 49.6795 - accuracy: 0.6836
# Epoch 10/100
# ...

# %% [markdown]
# ![Learning Rate.webp](data:image/webp;base64,...)

# %% [markdown]
# ![1662417016853.png](data:image/png;base64,...)

# %% [markdown]
# ![This-figure-Shows-multi-SGD-optimizer.png](data:image/png;base64,...)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (32, 30)                  360
#
#  dense_1 (Dense)             (32, 15)                  465
#
#  dense_2 (Dense)             (32, 1)                   16
#
# ...
# Total params: 841
# Trainable params: 841
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model


# Generate a graphical visualization of the model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ![How-to-Choose-an-Output-Layer-Activation-Functionnnnn.png](data:image/png;base64,...)

# %% [markdown]
# ![Neural_network_internal_layout_utilizing_one_vs_all_approach_2_11zon_8c87738b43.webp](data:image/webp;base64,...)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train ,y_train, batch_size = 50, epochs = 300, validation_split = 0.2)
# Out:
# Epoch 1/300
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5203 - accuracy: 0.7630 - val_loss: 0.4537 - val_accuracy: 0.7987
# Epoch 2/300
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.8064 - val_loss: 0.4254 - val_accuracy: 0.8112
# Epoch 3/300
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4043 - accuracy: 0.8263 - val_loss: 0.4026 - val_accuracy: 0.8319
# Epoch 4/300
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8381 - val_loss: 0.3844 - val_accuracy: 0.8431
# Epoch 5/300
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8462 - val_loss: 0.3715 - val_accuracy: 0.8494
# Epoch 6/300
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8523 - val_loss: 0.3647 - val_accuracy: 0.8481
# Epoch 7/300
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (50, 30)                  360
#
#  dense_4 (Dense)             (50, 15)                  465
#
#  dense_5 (Dense)             (50, 1)                   16
#
# ...
# Total params: 841
# Trainable params: 841
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model2.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()

# %%
model = Sequential()

model.add(Dense(80, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train ,y_train, batch_size = 16, epochs = 150, validation_split = 0.2)
# Out:
# Epoch 1/150
# 400/400 [==============================] - 2s 3ms/step - loss: 0.4414 - accuracy: 0.8059 - val_loss: 0.3775 - val_accuracy: 0.8400
# Epoch 2/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3556 - accuracy: 0.8523 - val_loss: 0.3677 - val_accuracy: 0.8481
# Epoch 3/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3425 - accuracy: 0.8602 - val_loss: 0.3563 - val_accuracy: 0.8569
# Epoch 4/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3358 - accuracy: 0.8639 - val_loss: 0.3560 - val_accuracy: 0.8562
# Epoch 5/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3310 - accuracy: 0.8658 - val_loss: 0.3500 - val_accuracy: 0.8544
# Epoch 6/150
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3252 - accuracy: 0.8666 - val_loss: 0.3623 - val_accuracy: 0.8400
# Epoch 7/150
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (16, 80)                  960
#
#  dense_7 (Dense)             (16, 50)                  4050
#
#  dense_8 (Dense)             (16, 50)                  2550
#
#  dense_9 (Dense)             (16, 20)                  1020
#
#  dense_10 (Dense)            (16, 1)                   21
#
# ...
# Total params: 8,601
# Trainable params: 8,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model3.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()

# %%
from keras.layers import Dense, Dropout
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.2))  # Dropout layer for regularization
model.add(Dense(1, activation='sigmoid'))

# %%
from keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=150, validation_split=0.2)
# Out:
# Epoch 1/150
# 400/400 [==============================] - 2s 3ms/step - loss: 0.5037 - accuracy: 0.7636 - val_loss: 0.4373 - val_accuracy: 0.8075
# Epoch 2/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4347 - accuracy: 0.8134 - val_loss: 0.4206 - val_accuracy: 0.8131
# Epoch 3/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4156 - accuracy: 0.8248 - val_loss: 0.4049 - val_accuracy: 0.8219
# Epoch 4/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8347 - val_loss: 0.3906 - val_accuracy: 0.8400
# Epoch 5/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3857 - accuracy: 0.8427 - val_loss: 0.3813 - val_accuracy: 0.8419
# Epoch 6/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3768 - accuracy: 0.8455 - val_loss: 0.3739 - val_accuracy: 0.8475
# Epoch 7/150
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 32)                384
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_12 (Dense)            (None, 1)                 33
#
# ...
# Total params: 417
# Trainable params: 417
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model4.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu',))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=150, validation_split=0.2)
# Out:
# Epoch 1/150
# 400/400 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7364 - val_loss: 0.4353 - val_accuracy: 0.8069
# Epoch 2/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4355 - accuracy: 0.8114 - val_loss: 0.4064 - val_accuracy: 0.8244
# Epoch 3/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4140 - accuracy: 0.8267 - val_loss: 0.3900 - val_accuracy: 0.8356
# Epoch 4/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4047 - accuracy: 0.8289 - val_loss: 0.3783 - val_accuracy: 0.8425
# Epoch 5/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3879 - accuracy: 0.8355 - val_loss: 0.3686 - val_accuracy: 0.8519
# Epoch 6/150
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3837 - accuracy: 0.8414 - val_loss: 0.3657 - val_accuracy: 0.8500
# Epoch 7/150
# ...

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 32)                384
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_15 (Dense)            (None, 1)                 17
#
# ...
# Total params: 929
# Trainable params: 929
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model5.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')


plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()

# %%
from tensorflow.keras.optimizers import SGD
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.2))  # Dropout layer for regularization
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer = SGD(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=150, validation_split=0.2)
# Out:
# Epoch 1/150
# 400/400 [==============================] - 2s 4ms/step - loss: 0.7316 - accuracy: 0.5053 - val_loss: 0.6493 - val_accuracy: 0.6394
# Epoch 2/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6131 - accuracy: 0.7070 - val_loss: 0.5758 - val_accuracy: 0.7650
# Epoch 3/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5631 - accuracy: 0.7633 - val_loss: 0.5394 - val_accuracy: 0.7894
# Epoch 4/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7803 - val_loss: 0.5191 - val_accuracy: 0.7956
# Epoch 5/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5221 - accuracy: 0.7908 - val_loss: 0.5067 - val_accuracy: 0.7969
# Epoch 6/150
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5116 - accuracy: 0.7912 - val_loss: 0.4980 - val_accuracy: 0.7962
# Epoch 7/150
# ...

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 32)                384
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_21 (Dense)            (None, 1)                 33
#
# ...
# Total params: 417
# Trainable params: 417
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model6.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models


# Step 1: Load and Explore the MNIST Dataset

# Load the MNIST dataset, which consists of 28x28 grayscale images of handwritten digits (0-9).
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# The training dataset contains 60,000 images, and the test dataset contains 10,000 images.
print("Number of training samples:", len(train_images))
print("Number of test samples:", len(test_images))
# Out:
# Number of training samples: 60000
# Number of test samples: 10000

# %%
# Show an example image from the dataset
plt.figure()
plt.imshow(train_images[0], cmap='gray')
plt.title(f"Label: {train_labels[0]}")
plt.show()

# %%
# Step 2: Preprocess the Data

# Reshape the images to have a single color channel (grayscale) and normalize pixel values to [0, 1].
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# One-hot encode the labels.
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Select a few random images from the training dataset
sample_images = train_images[:5]

# Display the selected images along with their labels
plt.figure(figsize=(12, 5))

for i, image in enumerate(sample_images):
    plt.subplot(1, 5, i + 1)
    plt.imshow(image.reshape(28, 28), cmap='gray')
    plt.title(f"Label: {train_labels[i].argmax()}")

plt.show()

# %%
# Step 3: Build the Deep Learning Model

# Create a sequential model, which allows us to build a neural network layer by layer.
model = models.Sequential()

# Add the first convolutional layer with 32 filters, each of size (3, 3), and ReLU activation.
# Input shape is (28, 28, 1) for grayscale images.
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))

# Add a max-pooling layer to downsample the spatial dimensions.
model.add(layers.MaxPooling2D((2, 2)))

# Add another convolutional layer with 64 filters and ReLU activation.
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Add another max-pooling layer.
model.add(layers.MaxPooling2D((2, 2)))

# Add a third convolutional layer with 64 filters and ReLU activation.
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Flatten the output from 2D to 1D for the fully connected layers.
model.add(layers.Flatten())

# Add a dense (fully connected) layer with 64 units and ReLU activation.
model.add(layers.Dense(64, activation='relu'))

# Add the output layer with 10 units (one for each digit 0-9) and softmax activation.
model.add(layers.Dense(10, activation='softmax'))

# %%
# Step 4: Compile the Model

# Compile the model with the Adam optimizer, categorical cross-entropy loss for multi-class classification,
# and metrics to measure during training (accuracy in this case).
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Step 5: Train the Model

# Train the model on the training data with 5 epochs and a batch size of 64.
history = model.fit(train_images, train_labels, epochs=5, batch_size=64,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 67s 71ms/step - loss: 0.1814 - accuracy: 0.9443 - val_loss: 0.0466 - val_accuracy: 0.9854
# Epoch 2/5
# 938/938 [==============================] - 65s 69ms/step - loss: 0.0490 - accuracy: 0.9848 - val_loss: 0.0424 - val_accuracy: 0.9854
# Epoch 3/5
# 938/938 [==============================] - 64s 69ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.0325 - val_accuracy: 0.9895
# Epoch 4/5
# 938/938 [==============================] - 62s 67ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.0254 - val_accuracy: 0.9923
# Epoch 5/5
# 938/938 [==============================] - 66s 70ms/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.0260 - val_accuracy: 0.9923

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense_16 (Dense)            (None, 64)                36928
#
#  dense_17 (Dense)            (None, 10)                650
#
# ...
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='mnist.png', show_shapes=True, show_layer_names=True)

# %%
plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')


plt.show()

# %%
plt.plot(history.history['accuracy'], label='Acuuracy')

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.legend()

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')

plt.show()
